# %% [markdown]
# # GraphFlow

# %%
import asyncio
from autogen_agentchat.agents import AssistantAgent,UserProxyAgent
from autogen_agentchat.teams import SelectorGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import TextMentionTermination
from dotenv import load_dotenv
import os

# Load API key
load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

# Model client
model_client = OpenAIChatCompletionClient(model='gpt-4o', api_key=api_key)

# %% [markdown]
# DigraphBuilder
# GraphFlow

# %%
from autogen_agentchat.teams import DiGraphBuilder, GraphFlow

# %% [markdown]
# # Sequential Flow

# %%
writer = AssistantAgent(
    name="Writer",
    description="A writer agent that generates text based on user input.",
    model_client=model_client,
    system_message="You are a creative writer. Please write a story based on the user's input.",
)

reviewer = AssistantAgent(
    name="Reviewer",
    description="A reviewer agent that provides feedback on the text generated by the writer.",
    model_client=model_client,
    system_message="You are a reviewer. Please provide feedback on the text generated by the writer.",
)

# %%
builder = DiGraphBuilder()
builder.add_node(writer).add_node(reviewer)
builder.add_edge(writer, reviewer)

graph = builder.build()

# %%
graph
# Out:
# DiGraph(nodes={'Writer': DiGraphNode(name='Writer', edges=[DiGraphEdge(target='Reviewer', condition=None, condition_function=None, activation_group='Reviewer', activation_condition='all')], activation='all'), 'Reviewer': DiGraphNode(name='Reviewer', edges=[], activation='all')}, default_start_node=None)

# %% [markdown]
# DiGraph(nodes={'Writer': DiGraphNode(name='Writer', edges=[DiGraphEdge(target='Reviewer', condition=None, condition_function=None, activation_group='Reviewer', activation_condition='all')], activation='all'), 'Reviewer': DiGraphNode(name='Reviewer', edges=[], activation='all')}, default_start_node=None)

# %%
team = GraphFlow([writer,reviewer], graph)

# %%
stream = team.run_stream(task ="Write a good poem about India in less than 30 words.")

async for event in stream:
    print(event)
# Out:
# id='cac05749-0c15-4c5a-b5ac-8eb0f3729496' source='user' models_usage=None metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 45, 13, 266135, tzinfo=datetime.timezone.utc) content='Write a good poem about India in less than 30 words.' type='TextMessage'
# id='7616a5da-c1cd-4ae7-a3d5-7482f80985c1' source='Writer' models_usage=RequestUsage(prompt_tokens=41, completion_tokens=36) metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 45, 15, 581718, tzinfo=datetime.timezone.utc) content="Land of vibrant hues and ancient lore,  \nWhere rivers dance and peacocks soar.  \nBound by spirit, vast and free,  \nIndia sings in unity's key.  " type='TextMessage'
# ...

# %%
source='user' models_usage=None metadata={} content='Write a good poem about India in less than 30 words.' type='TextMessage'
source='Writer' models_usage=RequestUsage(prompt_tokens=409, completion_tokens=39) metadata={} content='India, a vibrant tapestry spun,  \nWith rivers, deserts, land of sun.  \nCulture diverse, festivals bright,  \nUnity in every light.  \nAncient tales in modern flight.  ' type='TextMessage'
source='Reviewer' models_usage=RequestUsage(prompt_tokens=791, completion_tokens=233) metadata={} content='This concise poem effectively captures the essence of India using limited words. It manages to convey the country\'s natural beauty, cultural diversity, and the blend of ancient and modern elements.\n\nStrengths:\n1. **Economy of Language**: You\'ve managed to encapsulate the complexity of India in a few words, maintaining a clear and coherent message.\n2. **Imagery**: The mention of "rivers, deserts, land of sun" immediately sparks vivid imagery, grounding the reader in India\'s diverse landscapes.\n3. **Cultural Highlight**: Phrases like "Culture diverse, festivals bright" succinctly highlight the rich cultural tapestry of the country.\n4. **Unity Theme**: The line "Unity in every light" effectively underscores the theme of unity amidst diversity.\n\nSuggestions for Improvement:\n1. **Rhythm and Flow**: Consider adjusting the last line slightly to enhance the rhythmic flow or provide a stronger ending. An alternative could be something like "Ancient tales, modern heights."\n\nOverall, this short poem successfully conveys the richness of India’s landscape and culture, giving readers a brief yet powerful snapshot. With minor tweaks, it can become even more resonant.' type='TextMessage'
source='DiGraphStopAgent' models_usage=None metadata={} content='Digraph execution is complete' type='StopMessage'




messages=[TextMessage(source='user', models_usage=None, metadata={}, content='Write a good poem about India in less than 30 words.', type='TextMessage'), TextMessage(source='Writer', models_usage=RequestUsage(prompt_tokens=409, completion_tokens=39), metadata={}, content='India, a vibrant tapestry spun,  \nWith rivers, deserts, land of sun.  \nCulture diverse, festivals bright,  \nUnity in every light.  \nAncient tales in modern flight.  ', type='TextMessage'), TextMessage(source='Reviewer', models_usage=RequestUsage(prompt_tokens=791, completion_tokens=233), metadata={}, content='This concise poem effectively captures the essence of India using limited words. It manages to convey the country\'s natural beauty, cultural diversity, and the blend of ancient and modern elements.\n\nStrengths:\n1. **Economy of Language**: You\'ve managed to encapsulate the complexity of India in a few words, maintaining a clear and coherent message.\n2. **Imagery**: The mention of "rivers, deserts, land of sun" immediately sparks vivid imagery, grounding the reader in India\'s diverse landscapes.\n3. **Cultural Highlight**: Phrases like "Culture diverse, festivals bright" succinctly highlight the rich cultural tapestry of the country.\n4. **Unity Theme**: The line "Unity in every light" effectively underscores the theme of unity amidst diversity.\n\nSuggestions for Improvement:\n1. **Rhythm and Flow**: Consider adjusting the last line slightly to enhance the rhythmic flow or provide a stronger ending. An alternative could be something like "Ancient tales, modern heights."\n\nOverall, this short poem successfully conveys the richness of India’s landscape and culture, giving readers a brief yet powerful snapshot. With minor tweaks, it can become even more resonant.', type='TextMessage'), StopMessage(source='DiGraphStopAgent', models_usage=None, metadata={}, content='Digraph execution is complete', type='StopMessage')] stop_reason='Stop message received'
# Out:
#   Cell In[13], line 1
#     source='user' models_usage=None metadata={} content='Write a good poem about India in less than 30 words.' type='TextMessage'
#                   ^
# SyntaxError: invalid syntax

# %%
import asyncio

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import MaxMessageTermination
from autogen_agentchat.teams import DiGraphBuilder, GraphFlow
from autogen_ext.models.openai import OpenAIChatCompletionClient


async def main():
    # Initialize agents with OpenAI model clients.
    model_client = OpenAIChatCompletionClient(model="gpt-4.1-nano")
    agent_a = AssistantAgent("A", model_client=model_client, system_message="You are a helpful assistant.")
    agent_b = AssistantAgent("B", model_client=model_client, system_message="Translate input to Chinese.")
    agent_c = AssistantAgent("C", model_client=model_client, system_message="Translate input to Japanese.")

    # Create a directed graph with fan-out flow A -> (B, C).
    builder = DiGraphBuilder()
    builder.add_node(agent_a).add_node(agent_b).add_node(agent_c)
    builder.add_edge(agent_a, agent_b).add_edge(agent_a, agent_c)
    graph = builder.build()

    # Create a GraphFlow team with the directed graph.
    team = GraphFlow(
        participants=[agent_a, agent_b, agent_c],
        graph=graph,
        termination_condition=MaxMessageTermination(5),
    )

    # Run the team and print the events.
    async for event in team.run_stream(task="Write a short story about a cat."):
        print(event)


asyncio.run(main())
# Out:
# id='acb6109b-fe5e-442a-8861-f27b8fd6e71e' source='user' models_usage=None metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 50, 41, 167070, tzinfo=datetime.timezone.utc) content='Write a short story about a cat.' type='TextMessage'
# ...

# %%
import asyncio

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import MaxMessageTermination
from autogen_agentchat.teams import DiGraphBuilder, GraphFlow
from autogen_ext.models.openai import OpenAIChatCompletionClient



    # Initialize agents with OpenAI model clients.
model_client = OpenAIChatCompletionClient(model="gpt-4.1-nano")
agent_a = AssistantAgent("A", model_client=model_client, system_message="You are a helpful assistant.")
agent_b = AssistantAgent("B", model_client=model_client, system_message="Translate input to Chinese.")
agent_c = AssistantAgent("C", model_client=model_client, system_message="Translate input to Japanese.")
agent_d = AssistantAgent("D", model_client=model_client, system_message="Summarize.")


# Create a directed graph with fan-out flow A -> (B, C).
builder = DiGraphBuilder()
builder.add_node(agent_a).add_node(agent_b).add_node(agent_c).add_node(agent_d)
builder.add_edge(agent_a, agent_b).add_edge(agent_a, agent_c)
builder.add_edge(agent_b, agent_d).add_edge(agent_c, agent_d)
graph = builder.build()

# Create a GraphFlow team with the directed graph.
team = GraphFlow(
    participants=[agent_a, agent_b, agent_c, agent_d],
    graph=graph,
    termination_condition=MaxMessageTermination(5),
)

# Run the team and print the events.
async for event in team.run_stream(task="Write a short story about a cat."):
    print(event)
# Out:
# id='d3509f7a-8f9e-43fa-810b-e210492f55d3' source='user' models_usage=None metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 53, 21, 764636, tzinfo=datetime.timezone.utc) content='Write a short story about a cat.' type='TextMessage'
# ...

# %%
id='238d5de6-4113-4090-aac8-71f836d80149' source='user' models_usage=None metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 52, 5, 559302, tzinfo=datetime.timezone.utc) content='Write a short story about a cat.' type='TextMessage'
id='a3f4964c-c520-4b13-8f61-1454ce8a1a02' source='A' models_usage=RequestUsage(prompt_tokens=26, completion_tokens=232) metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 52, 7, 105212, tzinfo=datetime.timezone.utc) content='Once upon a time, in a cozy little town, there lived a curious cat named Whiskers. With soft gray fur and shining green eyes, Whiskers loved nothing more than to explore every nook and cranny of his neighborhood.\n\nOne sunny morning, Whiskers discovered a narrow alley he had never ventured down before. Intrigued, he squeezed through a gap between two fences and found himself in a secret garden, filled with vibrant flowers and fluttering butterflies. In the center stood an ancient oak tree with a sturdy branch perfect for climbing.\n\nAs Whiskers leapt onto the branch, he realized he had found his new favorite spot. From up high, he watched squirrels scurrying and listened to the cheerful chirping of birds. It was a place of wonder and peaceful solitude.\n\nFrom that day on, Whiskers visited the secret garden every morning, exploring its magic and making new friends among the creatures that lived there. No matter where his adventures took him, he always carried the joy of discovery in his heart.\n\nAnd so, the curious cat’s adventures brought happiness not only to him but also to everyone who heard his tale.' type='TextMessage'
id='93f6585d-4519-45a1-8191-4eb33596a97a' source='B' models_usage=RequestUsage(prompt_tokens=262, completion_tokens=339) metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 52, 9, 689695, tzinfo=datetime.timezone.utc) content='从前，在一个温馨的小镇上，住着一只好奇心很强的猫，名字叫胡须。胡须拥有柔软的灰色毛发和闪亮的绿色眼睛，他最喜欢的事情就是探索邻里四处的角落和缝隙。\n\n一天阳光明媚的早晨，胡须发现了一条以前从未走过的狭窄巷子。出于好奇，他挤过两堵篱笆之间的缝隙，来到一个秘密花园中，那里盛开着五彩缤纷的花朵，蝴蝶在空中翩翩起舞。花园中央是一棵古老的橡树，树上有一根结实的树枝，非常适合攀爬。\n\n胡须跳上树枝时，顿时觉得找到了自己最喜欢的地方。从高高的树枝上，他可以看到松鼠们在树间穿梭，聆听鸟儿们愉快的鸣叫声。那是一个充满奇迹和宁静的好去处。\n\n从那天起，胡须每天早晨都会来到这个秘密花园，探索它的奇妙，结交在那里生活的各种小动物朋友。无论他的冒险带他去到哪里，他的内心总怀着一种发现新奇的喜悦。\n\n就这样，好奇的猫胡须的冒险不仅带给他自己快乐，也让所有听到他故事的人都感到温暖和欢欣。' type='TextMessage'
id='2b8c811e-9151-479a-bf2e-c048bafe01dd' source='C' models_usage=RequestUsage(prompt_tokens=262, completion_tokens=382) metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 52, 10, 480696, tzinfo=datetime.timezone.utc), content='むかしむかし、暖かくて小さな町に、好奇心旺盛な猫のウィスカーズが住んでいました。柔らかな灰色の毛に輝く緑の目を持つウィスカーズは、近所の隅々まで探検することを何よりも愛していました。\n\nある晴れた朝、ウィスカーズは今まで入ったことのない細い路地を見つけました。興味津々で、フェンスの間の隙間をすり抜けると、色とりどりの花が咲き、蝶々がひらひら舞う秘密の庭にたどり着きました。中央には、登るのにぴったりな丈夫な枝を持つ古いオークの木が立っていました。\n\nウィスカーズはその枝に飛び乗ると、新しいお気に入りの場所を見つけたことに気づきました。高いところから、リスが走り回るのを見たり、鳥たちの陽気なさえずりを聞いたりして、驚きと静かな平和を感じました。\n\nそれからというもの、ウィスカーズは毎朝秘密の庭を訪れ、その魔法を探検し、そこに住む生き物たちと友達になっていきました。どこへ冒険に出かけても、彼はいつも発見の喜びを胸に抱いていました。\n\nこうして、好奇心いっぱいの猫の冒険は、彼だけでなく、彼の物語を聞いたみんなに幸せをもたらしたのです。' type='TextMessage'
id='a6ecfb80-5184-4c10-800b-c8b8e317e3e6' source='D' models_usage=RequestUsage(prompt_tokens=991, completion_tokens=344) metadata={} created_at=datetime.datetime(2025, 7, 19, 4, 52, 13, 222107, tzinfo=datetime.timezone.utc), content='昔々、温かな街に好奇心旺盛な猫のウィスカーズが住んでいました。灰色の毛と輝く緑の目を持つ彼は、町のさまざまな隅々を探検するのが大好きでした。\n\nある晴れた朝、ウィスカーズは初めて通る細い路地を見つけました。興味津々でフェンスの隙間をくぐると、色とりどりの花が咲き、蝶々が舞う秘密の庭にたどり着きました。庭の中央には、登るのにぴったりな丈夫な枝を持つ古いオークの木が立っていました。\n\nウィスカーズはその枝に飛び乗り、高いところから周りを見渡しました。リスが走り回る姿や鳥たちの陽気なさえずりを見ながら、静かで不思議な平和を感じました。\n\nそれ以来、ウィスカーズは毎朝この秘密の庭を訪れ、魔法のような場所を探検しながら、そこで暮らす仲間たちと友情を育んでいきました。どこへ冒険に出かけても、いつも新しい発見の喜びを胸に抱いていました。\n\nこうして、好奇心いっぱいの猫ウィスカーズの冒険は、彼だけでなく、彼の物語を聞いた皆も幸せにしました。' type='TextMessage'
messages=[TextMessage(id='238d5de6-4113-4090-aac8-71f836d80149', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 19, 4, 52, 5, 559302, tzinfo=datetime.timezone.utc), content='Write a short story about a cat.', type='TextMessage'), TextMessage(id='a3f4964c-c520-4b13-8f61-1454ce8a1a02', source='A', models_usage=RequestUsage(prompt_tokens=26, completion_tokens=232), metadata={}, created_at=datetime.datetime(2025, 7, 19, 4, 52, 7, 105212, tzinfo=datetime.timezone.utc), content='Once upon a time, in a cozy little town, there lived a curious cat named Whiskers. With soft gray fur and shining green eyes, Whiskers loved nothing more than to explore every nook and cranny of his neighborhood.\n\nOne sunny morning, Whiskers discovered a narrow alley he had never ventured down before. Intrigued, he squeezed through a gap between two fences and found himself in a secret garden, filled with vibrant flowers and fluttering butterflies. In the center stood an ancient oak tree with a sturdy branch perfect for climbing.\n\nAs Whiskers leapt onto the branch, he realized he had found his new favorite spot. From up high, he watched squirrels scurrying and listened to the cheerful chirping of birds. It was a place of wonder and peaceful solitude.\n\nFrom that day on, Whiskers visited the secret garden every morning, exploring its magic and making new friends among the creatures that lived there. No matter where his adventures took him, he always carried the joy of discovery in his heart.\n\nAnd so, the curious cat’s adventures brought happiness not only to him but also to everyone who heard his tale.', type='TextMessage'), TextMessage(id='93f6585d-4519-45a1-8191-4eb33596a97a', source='B', models_usage=RequestUsage(prompt_tokens=262, completion_tokens=339), metadata={}, created_at=datetime.datetime(2025, 7, 19, 4, 52, 9, 689695, tzinfo=datetime.timezone.utc), content='从前，在一个温馨的小镇上，住着一只好奇心很强的猫，名字叫胡须。胡须拥有柔软的灰色毛发和闪亮的绿色眼睛，他最喜欢的事情就是探索邻里四处的角落和缝隙。\n\n一天阳光明媚的早晨，胡须发现了一条以前从未走过的狭窄巷子。出于好奇，他挤过两堵篱笆之间的缝隙，来到一个秘密花园中，那里盛开着五彩缤纷的花朵，蝴蝶在空中翩翩起舞。花园中央是一棵古老的橡树，树上有一根结实的树枝，非常适合攀爬。\n\n胡须跳上树枝时，顿时觉得找到了自己最喜欢的地方。从高高的树枝上，他可以看到松鼠们在树间穿梭，聆听鸟儿们愉快的鸣叫声。那是一个充满奇迹和宁静的好去处。\n\n从那天起，胡须每天早晨都会来到这个秘密花园，探索它的奇妙，结交在那里生活的各种小动物朋友。无论他的冒险带他去到哪里，他的内心总怀着一种发现新奇的喜悦。\n\n就这样，好奇的猫胡须的冒险不仅带给他自己快乐，也让所有听到他故事的人都感到温暖和欢欣。', type='TextMessage'), TextMessage(id='2b8c811e-9151-479a-bf2e-c048bafe01dd', source='C', models_usage=RequestUsage(prompt_tokens=262, completion_tokens=382), metadata={}, created_at=datetime.datetime(2025, 7, 19, 4, 52, 10, 480696, tzinfo=datetime.timezone.utc), content='むかしむかし、暖かくて小さな町に、好奇心旺盛な猫のウィスカーズが住んでいました。柔らかな灰色の毛に輝く緑の目を持つウィスカーズは、近所の隅々まで探検することを何よりも愛していました。\n\nある晴れた朝、ウィスカーズは今まで入ったことのない細い路地を見つけました。興味津々で、フェンスの間の隙間をすり抜けると、色とりどりの花が咲き、蝶々がひらひら舞う秘密の庭にたどり着きました。中央には、登るのにぴったりな丈夫な枝を持つ古いオークの木が立っていました。\n\nウィスカーズはその枝に飛び乗ると、新しいお気に入りの場所を見つけたことに気づきました。高いところから、リスが走り回るのを見たり、鳥たちの陽気なさえずりを聞いたりして、驚きと静かな平和を感じました。\n\nそれからというもの、ウィスカーズは毎朝秘密の庭を訪れ、その魔法を探検し、そこに住む生き物たちと友達になっていきました。どこへ冒険に出かけても、彼はいつも発見の喜びを胸に抱いていました。\n\nこうして、好奇心いっぱいの猫の冒険は、彼だけでなく、彼の物語を聞いたみんなに幸せをもたらしたのです。', type='TextMessage'), TextMessage(id='a6ecfb80-5184-4c10-800b-c8b8e317e3e6', source='D', models_usage=RequestUsage(prompt_tokens=991, completion_tokens=344), metadata={}, created_at=datetime.datetime(2025, 7, 19, 4, 52, 13, 222107, tzinfo=datetime.timezone.utc), content='昔々、温かな街に好奇心旺盛な猫のウィスカーズが住んでいました。灰色の毛と輝く緑の目を持つ彼は、町のさまざまな隅々を探検するのが大好きでした。\n\nある晴れた朝、ウィスカーズは初めて通る細い路地を見つけました。興味津々でフェンスの隙間をくぐると、色とりどりの花が咲き、蝶々が舞う秘密の庭にたどり着きました。庭の中央には、登るのにぴったりな丈夫な枝を持つ古いオークの木が立っていました。\n\nウィスカーズはその枝に飛び乗り、高いところから周りを見渡しました。リスが走り回る姿や鳥たちの陽気なさえずりを見ながら、静かで不思議な平和を感じました。\n\nそれ以来、ウィスカーズは毎朝この秘密の庭を訪れ、魔法のような場所を探検しながら、そこで暮らす仲間たちと友情を育んでいきました。どこへ冒険に出かけても、いつも新しい発見の喜びを胸に抱いていました。\n\nこうして、好奇心いっぱいの猫ウィスカーズの冒険は、彼だけでなく、彼の物語を聞いた皆も幸せにしました。', type='TextMessage')] stop_reason='Digraph execution is complete'

# %%
import asyncio

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import MaxMessageTermination
from autogen_agentchat.teams import DiGraphBuilder, GraphFlow
from autogen_ext.models.openai import OpenAIChatCompletionClient


async def main():
    # Initialize agents with OpenAI model clients.
    model_client = OpenAIChatCompletionClient(model="gpt-4.1-nano")
    agent_a = AssistantAgent(
        "A",
        model_client=model_client,
        system_message="Detect if the input is in Chinese. If it is, say 'yes', else say 'no', and nothing else.",
    )
    agent_b = AssistantAgent("B", model_client=model_client, system_message="Translate input to English.")
    agent_c = AssistantAgent("C", model_client=model_client, system_message="Translate input to Chinese.")

    # Create a directed graph with conditional branching flow A -> B ("yes"), A -> C (otherwise).
    builder = DiGraphBuilder()
    builder.add_node(agent_a).add_node(agent_b).add_node(agent_c)
    # Create conditions as callables that check the message content.
    builder.add_edge(agent_a, agent_b, condition=lambda msg: "yes" in msg.to_model_text())
    builder.add_edge(agent_a, agent_c, condition=lambda msg: "yes" not in msg.to_model_text())
    graph = builder.build()

    # Create a GraphFlow team with the directed graph.
    team = GraphFlow(
        participants=[agent_a, agent_b, agent_c],
        graph=graph,
        termination_condition=MaxMessageTermination(5),
    )

    # Run the team and print the events.
    async for event in team.run_stream(task="AutoGen is a framework for building AI agents."):
        print(event)


asyncio.run(main())
